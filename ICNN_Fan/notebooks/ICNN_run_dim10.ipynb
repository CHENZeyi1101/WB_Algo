# %%
from __future__ import print_function
import logging
# import GPUtil

import sys
import os
import numpy as np
from tqdm import tqdm
import pandas as pd

# Get the parent folder path (folder K)
parent_folder_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

print(parent_folder_path)

sys.path.append(parent_folder_path)

from torch.autograd import Variable
import torch.utils.data
import torch.optim as optim
import torch
import numpy as np
import pandas as pd
import optimal_transport_modules.log_utils as LLU
import optimal_transport_modules.generate_data as g_data
import optimal_transport_modules.generate_NN as g_NN
import optimal_transport_modules.pytorch_utils as PTU
from optimal_transport_modules.record_mean_cov import select_mean_and_cov
from CNX.cfg import CNXCfgCustom as Cfg_class
import CNX.compare_dist_results as CDR
# Out:
# /Users/zeyichen/GitHub/Repo/WB_Algo/ICNN_Fan

# %%
dim = 10
num_samples = 5000
num_measures = 10
seed = 1009

# %%
##### For computing the constraint loss of negtive weights ######
def compute_constraint_loss(list_of_params):
    loss_val = 0
    for p in list_of_params:
        loss_val += torch.relu(-p).pow(2).sum()
    return loss_val

# %%
folder_name = f"ICNN_{num_measures}_seed_{seed}_samples_{num_samples}_dim_{dim}"
csv_path = f"./results/{folder_name}/input_and_source_samples/csv_files"

if os.path.exists(csv_path):
    print(f"The path '{csv_path}' exists.")
else:
    print(f"The path '{csv_path}' does not exist.")

# evaluation_dirc = "./Evaluate"
# os.makedirs(evaluation_dirc, exist_ok=True)
# Out:
# The path './results/ICNN_10_seed_1009_samples_5000_dim_10/input_and_source_samples/csv_files' exists.

# %%
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
                    Training function definition
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
############## For each function here, it's an epoch ##################

def train(epoch, csv_path):
    convex_f.train()
    convex_g.train()
    generator_h.train()

    # These values are just for saving data
    w2_loss_value_epoch = 0
    g_OT_loss_value_epoch = [0] * cfg.NUM_DISTRIBUTION
    g_constraints_loss_value_epoch = 0
    remaining_f_loss_value_epoch = [0] * cfg.NUM_DISTRIBUTION
    mu_2moment_loss_value_epoch = 0
    miu_mean_value_epoch = 0
    miu_var_value_epoch = 0

    """""""""""""""""""""""""""""""""""""""""""""""""""
                            Data
    """""""""""""""""""""""""""""""""""""""""""""""""""
    total_data = torch.empty(cfg.N_TRAIN_SAMPLES, cfg.INPUT_DIM, cfg.NUM_DISTRIBUTION + 1)

    for marg_id in range(cfg.NUM_DISTRIBUTION):
        df = pd.read_csv(f"{csv_path}/input_measure_samples_{marg_id}.csv", header=None)
        total_data[:, :, marg_id] = torch.from_numpy(df.to_numpy())

    total_data[:, :, -1] = torch.randn(cfg.N_TRAIN_SAMPLES, cfg.INPUT_DIM)

    train_loader = torch.utils.data.DataLoader(
        total_data, batch_size=cfg.BATCH_SIZE, shuffle=True, **kwargs)

    for batch_idx, real_data in enumerate(train_loader):
        # real_data = real_data.cuda(PTU.device)
        real_data = real_data.cpu()

        miu_i = real_data[:, :, 0:cfg.NUM_DISTRIBUTION]
        epsilon = real_data[:, :, cfg.NUM_DISTRIBUTION]
        miu_i = Variable(miu_i, requires_grad=True)
        epsilon = Variable(epsilon)

        # containing four distribution
        g_OT_loss_value_batch = [0] * cfg.NUM_DISTRIBUTION
        g_constraints_loss_value_batch = 0  # containing four g networks
        remaining_f_loss_value_batch = [0] * cfg.NUM_DISTRIBUTION
        mu_2moment_loss_value_batch = 0
        miu_mean_value_batch = torch.zeros([cfg.INPUT_DIM])
        miu_var_value_batch = np.zeros(
            [cfg.INPUT_DIM, cfg.INPUT_DIM])

        ######################################################
        #                Medium Loop Begin                   #
        ######################################################
        ######### Here iterate over a given number: cfg.N_Fnet_ITERS=4 ##
        for medium_iter in range(1, cfg.N_Fnet_ITERS + 1):

            ######################################################
            #                Inner Loop Begin                   #
            ######################################################
            ######### Here iterate over a given number: cfg.N_Gnet_ITERS=16 ##
            for inner_iter in range(1, cfg.N_Gnet_ITERS + 1):

                loss_g = torch.ones(cfg.NUM_DISTRIBUTION)
                for i in range(cfg.NUM_DISTRIBUTION):
                    optimizer_g[i].zero_grad()

                    # Get the gradient of g(y):=g(miu_i_data)
                    tmp_miu_i = miu_i[:, :, i]
                    g_of_y = convex_g[i](tmp_miu_i).sum()
                    grad_g_of_y = torch.autograd.grad(
                        g_of_y, tmp_miu_i, create_graph=True)[0]

                    # For each distribution you need to calculate a f(gradient of y)
                    # it's the mean of the batch
                    f_grad_g_y = convex_f[i](grad_g_of_y).mean()
                    # The 1st loss part useful for f/g parameters
                    loss_g[i] = f_grad_g_y - torch.dot(
                        grad_g_of_y.reshape(-1), miu_i[:, :, i].reshape(-1)) / cfg.BATCH_SIZE
                    g_OT_loss_value_batch[i] += loss_g[i].item()

                total_loss_g = loss_g.sum()
                total_loss_g.backward()
                # The 2nd loss part useful for g parameters:
                g_positive_constraints_loss = cfg.LAMBDA_CVX * \
                    compute_constraint_loss(
                        g_positive_params)
                g_constraints_loss_value_batch += g_positive_constraints_loss.item()
                g_positive_constraints_loss.backward()

                # ! update g
                for i in range(cfg.NUM_DISTRIBUTION):
                    optimizer_g[i].step()

                # Just for the last iteration keep the gradient on f intact
                if inner_iter != cfg.N_Gnet_ITERS:
                    for i in range(cfg.NUM_DISTRIBUTION):
                        optimizer_f[i].zero_grad()

            ######################################################
            #                Inner Loop Ends                     #
            ######################################################
            miu = generator_h(epsilon)
            # miu_mean = miu.mean(dim=0).cuda(PTU.device)
            miu_mean = miu.mean(dim = 0).cpu()
            # miu_var = np.cov(miu.cuda(PTU.device).detach().numpy().T)
            miu_var = np.cov(miu.cpu().detach().numpy().T)
            miu_mean_value_batch += miu_mean
            miu_var_value_batch += miu_var

            remaining_f_loss = torch.ones(cfg.NUM_DISTRIBUTION)
            # The 3rd loss part useful for f/h parameters
            for i in range(cfg.NUM_DISTRIBUTION):
                remaining_f_loss[i] = - convex_f[i](miu).mean()
                remaining_f_loss_value_batch[i] += remaining_f_loss[i].item()
            total_remaining_f_loss = remaining_f_loss.sum()
            total_remaining_f_loss.backward(retain_graph=True)

            # Flip the gradient sign for parameters in convex f
            # Because we need to solve "sup" of the loss for f
            for p in list(convex_f.parameters()):
                p.grad.copy_(-p.grad)
            # ! update f
            for i in range(cfg.NUM_DISTRIBUTION):
                optimizer_f[i].step()

            # Clamp the positive constraints on the convex_f_params
            for p in f_positive_params:
                p.data.copy_(torch.relu(p.data))

            if medium_iter != cfg.N_Fnet_ITERS:
                optimizer_h.zero_grad()

        ######################################################
        #               Medium Loop Ends                     #
        ######################################################
        # The 4th loss part useful for h parameters:
        # ? keep untouched for all weights
        # mu_2moment_loss_value_batch is total 4 distributions combined F
        mu_2moment_loss = 0.5 * \
            miu.pow(2).sum(dim=1).mean() * cfg.NUM_DISTRIBUTION
        mu_2moment_loss_value_batch += mu_2moment_loss.item() / cfg.NUM_DISTRIBUTION

        # ! update h
        mu_2moment_loss.backward()
        optimizer_h.step()
        # The four parts loss gradients are accumulated

        miu_mean_value_batch = miu_mean_value_batch / cfg.N_Fnet_ITERS
        miu_var_value_batch = miu_var_value_batch / cfg.N_Fnet_ITERS

        g_OT_loss_value_batch[:] = [
            item / (cfg.N_Gnet_ITERS * cfg.N_Fnet_ITERS) for item in g_OT_loss_value_batch]
        remaining_f_loss_value_batch[:] = [
            item / cfg.N_Fnet_ITERS for item in remaining_f_loss_value_batch]
        g_constraints_loss_value_batch /= (cfg.N_Gnet_ITERS *
                                           cfg.N_Fnet_ITERS)

        ##### Calculate W2 batch loss ###############
        w2_loss_value_batch = (sum(g_OT_loss_value_batch) + sum(remaining_f_loss_value_batch)) / cfg.NUM_DISTRIBUTION + \
            mu_2moment_loss_value_batch + 0.5 * \
            miu_i.pow(2).sum(dim=1).mean().item()
        w2_loss_value_batch *= 2
        # miu_i.pow(2).sum(dim=1).mean().item() is already the mean of all distributions

        ##### Calculate all epoch loss ###############
        w2_loss_value_epoch += w2_loss_value_batch
        miu_mean_value_epoch += miu_mean_value_batch
        miu_var_value_epoch += miu_var_value_batch

        g_OT_loss_value_epoch = [
            a + b for a,
            b in zip(
                g_OT_loss_value_epoch,
                g_OT_loss_value_batch)]
        g_constraints_loss_value_epoch += g_constraints_loss_value_batch
        remaining_f_loss_value_epoch = [
            a + b for a,
            b in zip(
                remaining_f_loss_value_epoch,
                remaining_f_loss_value_batch)]
        mu_2moment_loss_value_epoch += mu_2moment_loss_value_batch

        if batch_idx % cfg.log_interval == 0:
            logging.info('Train_Epoch: {} [{}/{} ({:.0f}%)] avg_dstb_g_OT_loss: {:.4f} avg_dstb_remaining_f_loss: {:.4f} mu_2moment_loss: {:.4f} g_constraint_loss: {:.4f} W2_loss: {:.4f} '.format(
                epoch,
                batch_idx * len(real_data),
                len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                sum(g_OT_loss_value_batch) / cfg.NUM_DISTRIBUTION,
                sum(remaining_f_loss_value_batch) / cfg.NUM_DISTRIBUTION,
                mu_2moment_loss_value_batch,
                miu_mean_value_batch.mean().tolist(),
                miu_var_value_batch.mean().tolist(),
                g_constraints_loss_value_batch,
                w2_loss_value_batch
            ))

    w2_loss_value_epoch /= len(train_loader)
    g_OT_loss_value_epoch[:] = [
        item / len(train_loader) for item in g_OT_loss_value_epoch]
    g_constraints_loss_value_epoch /= len(train_loader)
    remaining_f_loss_value_epoch[:] = [
        item / len(train_loader) for item in remaining_f_loss_value_epoch]
    mu_2moment_loss_value_epoch /= len(train_loader)
    miu_mean_value_epoch /= len(train_loader)
    miu_var_value_epoch /= len(train_loader)
    if cfg.high_dim_flag:
        results.add(epoch=epoch,
                    w2_loss_train_samples=w2_loss_value_epoch,
                    g_OT_train_loss=g_OT_loss_value_epoch,
                    g_constraints_train_loss=g_constraints_loss_value_epoch,
                    remaining_f_train_loss=remaining_f_loss_value_epoch,
                    mu_2moment_train_loss=mu_2moment_loss_value_epoch
                    )
    else:
        results.add(epoch=epoch,
                    w2_loss_train_samples=w2_loss_value_epoch,
                    g_OT_train_loss=g_OT_loss_value_epoch,
                    g_constraints_train_loss=g_constraints_loss_value_epoch,
                    remaining_f_train_loss=remaining_f_loss_value_epoch,
                    mu_2moment_train_loss=mu_2moment_loss_value_epoch,
                    miu_mean_train=miu_mean_value_epoch.tolist(),
                    miu_var_train=miu_var_value_epoch.tolist()
                    )
    results.save()

# %%
num_samples_evaluate = 5000
input_measure_samples_for_evaluation = {}
for marg_id in range(num_measures):
    df = pd.read_csv(f"{csv_path}/input_measure_samples_{marg_id}.csv", header=None)
    sampled_df = df.sample(n=1000, random_state=42)
    samples = sampled_df.to_numpy()
    input_measure_samples_for_evaluation[marg_id] = samples

# %%
if __name__ == '__main__':
    cfg = Cfg_class(DIM = dim, NUM_DISTRIBUTION=num_measures)

    # gpus_choice = GPUtil.getFirstAvailable(
    #     order='random', maxLoad=0.5, maxMemory=0.5, attempts=5, interval=900, verbose=False)
    # PTU.set_gpu_mode(True, gpus_choice[0])
    PTU.set_gpu_mode(False, 0)

    cfg.INPUT_DIM = dim
    cfg.OUTPUT_DIM = cfg.INPUT_DIM
    cfg.NUM_DISTRIBUTION = num_measures
    cfg.high_dim_flag = False
    cfg.epochs = 500
    results_save_path, model_save_path, results, testresults = LLU.init_path(cfg)
    # kwargs = {'num_workers': 4, 'pin_memory': True}
    kwargs = {'pin_memory': True}

    
    convex_f, convex_g, generator_h = g_NN.generate_FixedWeight_NN(cfg)

    """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
            Initialization with some positive parameters
    """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
    f_positive_params = []
    g_positive_params = []

    for i in range(cfg.NUM_DISTRIBUTION):
        for p in list(convex_f[i].parameters()):
            if hasattr(p, 'be_positive'):
                f_positive_params.append(p)

        for p in list(convex_g[i].parameters()):
            if hasattr(p, 'be_positive'):
                g_positive_params.append(p)

        # convex_f[i].cuda(PTU.device)
        # convex_g[i].cuda(PTU.device)
        convex_f[i].cpu()
        convex_g[i].cpu()
    # generator_h.cuda(PTU.device)
    generator_h.cpu()

    optimizer_f = []
    optimizer_g = []
    if cfg.optimizer is 'Adam':
        for i in range(cfg.NUM_DISTRIBUTION):
            optimizer_f.append(optim.Adam(convex_f[i].parameters(), lr=cfg.LR_f))
            optimizer_g.append(
                optim.Adam(convex_g[i].parameters(), lr=cfg.LR_g))
        optimizer_h = optim.Adam(
            generator_h.parameters(),
            lr=cfg.LR_h)


    """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
                        Real Training Process
    """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

    for epoch in range(1, cfg.epochs + 1):
        train(epoch, csv_path)
        if cfg.schedule_learning_rate:
            if epoch % cfg.lr_schedule_per_epoch == 0:
                for i in range(cfg.NUM_DISTRIBUTION):
                    optimizer_f[i].param_groups[0]['lr'] *= cfg.lr_schedule_scale
                    optimizer_g[i].param_groups[0]['lr'] *= cfg.lr_schedule_scale
                optimizer_h.param_groups[0]['lr'] *= cfg.lr_schedule_scale

        LLU.dump_nn(generator_h, convex_f, convex_g, epoch,
                    model_save_path, num_distribution=cfg.NUM_DISTRIBUTION, save_f=cfg.save_f)
# Out:
# <>:45: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:45: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /var/folders/ty/glwljgt93kv4cddc7b1kk26c0000gn/T/ipykernel_55042/1305659235.py:45: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cfg.optimizer is 'Adam':
# Train_Epoch: 1 [0/60000 (0%)] avg_dstb_g_OT_loss: -2179.5674 avg_dstb_remaining_f_loss: -0.2660 mu_2moment_loss: 0.5067 g_constraint_loss: 0.1504 W2_loss: 0.0059
# Train_Epoch: 1 [0/60000 (0%)] avg_dstb_g_OT_loss: -2179.5674 avg_dstb_remaining_f_loss: -0.2660 mu_2moment_loss: 0.5067 g_constraint_loss: 0.1504 W2_loss: 0.0059
# Train_Epoch: 1 [0/60000 (0%)] avg_dstb_g_OT_loss: -2179.5674 avg_dstb_remaining_f_loss: -0.2660 mu_2moment_loss: 0.5067 g_constraint_loss: 0.1504 W2_loss: 0.0059
# Train_Epoch: 1 [1000/60000 (2%)] avg_dstb_g_OT_loss: -17160.7442 avg_dstb_remaining_f_loss: -1.0767 mu_2moment_loss: 0.1883 g_constraint_loss: 0.0705 W2_loss: 0.0022
# Train_Epoch: 1 [1000/60000 (2%)] avg_dstb_g_OT_loss: -17160.7442 avg_dstb_remaining_f_loss: -1.0767 mu_2moment_loss: 0.1883 g_constraint_loss: 0.0705 W2_loss: 0.0022
# Train_Epoch: 1 [1000/60000 (2%)] avg_dstb_g_OT_loss: -17160.7442 avg_dstb_remaining_f_loss: -1.0767 mu_2moment_loss: 0.1883 g_constraint_loss: 0.0705 W2_loss: 0.0022
# Train_Epoch: 1 [2000/60000 (3%)] avg_dstb_g_OT_loss: -7184.1548 avg_dstb_remaining_f_loss: -2.9770 mu_2moment_loss: 0.2976 g_constraint_loss: 0.0545 W2_loss: 0.0025
# Train_Epoch: 1 [2000/60000 (3%)] avg_dstb_g_OT_loss: -7184.1548 avg_dstb_remaining_f_loss: -2.9770 mu_2moment_loss: 0.2976 g_constraint_loss: 0.0545 W2_loss: 0.0025
# Train_Epoch: 1 [2000/60000 (3%)] avg_dstb_g_OT_loss: -7184.1548 avg_dstb_remaining_f_loss: -2.9770 mu_2moment_loss: 0.2976 g_constraint_loss: 0.0545 W2_loss: 0.0025
# Train_Epoch: 1 [3000/60000 (5%)] avg_dstb_g_OT_loss: -4543.3243 avg_dstb_remaining_f_loss: -7.1146 mu_2moment_loss: 0.8721 g_constraint_loss: 0.0690 W2_loss: 0.0036
# Train_Epoch: 1 [3000/60000 (5%)] avg_dstb_g_OT_loss: -4543.3243 avg_dstb_remaining_f_loss: -7.1146 mu_2moment_loss: 0.8721 g_constraint_loss: 0.0690 W2_loss: 0.0036
# Train_Epoch: 1 [3000/60000 (5%)] avg_dstb_g_OT_loss: -4543.3243 avg_dstb_remaining_f_loss: -7.1146 mu_2moment_loss: 0.8721 g_constraint_loss: 0.0690 W2_loss: 0.0036
# Train_Epoch: 1 [4000/60000 (7%)] avg_dstb_g_OT_loss: -3766.3258 avg_dstb_remaining_f_loss: -15.3172 mu_2moment_loss: 1.9848 g_constraint_loss: 0.0850 W2_loss: 0.0044
# Train_Epoch: 1 [4000/60000 (7%)] avg_dstb_g_OT_loss: -3766.3258 avg_dstb_remaining_f_loss: -15.3172 mu_2moment_loss: 1.9848 g_constraint_loss: 0.0850 W2_loss: 0.0044
# Train_Epoch: 1 [4000/60000 (7%)] avg_dstb_g_OT_loss: -3766.3258 avg_dstb_remaining_f_loss: -15.3172 mu_2moment_loss: 1.9848 g_constraint_loss: 0.0850 W2_loss: 0.0044
# Train_Epoch: 1 [5000/60000 (8%)] avg_dstb_g_OT_loss: -2920.5130 avg_dstb_remaining_f_loss: -29.0728 mu_2moment_loss: 3.7158 g_constraint_loss: 0.0971 W2_loss: 0.0063
# Train_Epoch: 1 [5000/60000 (8%)] avg_dstb_g_OT_loss: -2920.5130 avg_dstb_remaining_f_loss: -29.0728 mu_2moment_loss: 3.7158 g_constraint_loss: 0.0971 W2_loss: 0.0063
# Train_Epoch: 1 [5000/60000 (8%)] avg_dstb_g_OT_loss: -2920.5130 avg_dstb_remaining_f_loss: -29.0728 mu_2moment_loss: 3.7158 g_constraint_loss: 0.0971 W2_loss: 0.0063
# Train_Epoch: 1 [6000/60000 (10%)] avg_dstb_g_OT_loss: -2268.0085 avg_dstb_remaining_f_loss: -49.3297 mu_2moment_loss: 6.2984 g_constraint_loss: 0.1066 W2_loss: 0.0079
# Train_Epoch: 1 [6000/60000 (10%)] avg_dstb_g_OT_loss: -2268.0085 avg_dstb_remaining_f_loss: -49.3297 mu_2moment_loss: 6.2984 g_constraint_loss: 0.1066 W2_loss: 0.0079
# Train_Epoch: 1 [6000/60000 (10%)] avg_dstb_g_OT_loss: -2268.0085 avg_dstb_remaining_f_loss: -49.3297 mu_2moment_loss: 6.2984 g_constraint_loss: 0.1066 W2_loss: 0.0079
# Train_Epoch: 1 [7000/60000 (12%)] avg_dstb_g_OT_loss: -2017.6552 avg_dstb_remaining_f_loss: -77.4380 mu_2moment_loss: 9.4581 g_constraint_loss: 0.1364 W2_loss: 0.0084
# Train_Epoch: 1 [7000/60000 (12%)] avg_dstb_g_OT_loss: -2017.6552 avg_dstb_remaining_f_loss: -77.4380 mu_2moment_loss: 9.4581 g_constraint_loss: 0.1364 W2_loss: 0.0084
# Train_Epoch: 1 [7000/60000 (12%)] avg_dstb_g_OT_loss: -2017.6552 avg_dstb_remaining_f_loss: -77.4380 mu_2moment_loss: 9.4581 g_constraint_loss: 0.1364 W2_loss: 0.0084
# Train_Epoch: 1 [12000/60000 (20%)] avg_dstb_g_OT_loss: -1034.8956 avg_dstb_remaining_f_loss: -397.1630 mu_2moment_loss: 53.1846 g_constraint_loss: 0.3067 W2_loss: 0.0211
# Train_Epoch: 1 [13000/60000 (22%)] avg_dstb_g_OT_loss: -975.5829 avg_dstb_remaining_f_loss: -495.3887 mu_2moment_loss: 70.8442 g_constraint_loss: 0.3081 W2_loss: 0.0338
# Train_Epoch: 1 [13000/60000 (22%)] avg_dstb_g_OT_loss: -975.5829 avg_dstb_remaining_f_loss: -495.3887 mu_2moment_loss: 70.8442 g_constraint_loss: 0.3081 W2_loss: 0.0338
# Train_Epoch: 1 [13000/60000 (22%)] avg_dstb_g_OT_loss: -975.5829 avg_dstb_remaining_f_loss: -495.3887 mu_2moment_loss: 70.8442 g_constraint_loss: 0.3081 W2_loss: 0.0338
# Train_Epoch: 1 [14000/60000 (23%)] avg_dstb_g_OT_loss: -938.5034 avg_dstb_remaining_f_loss: -603.1797 mu_2moment_loss: 89.8799 g_constraint_loss: 0.3441 W2_loss: 0.0668
# Train_Epoch: 1 [14000/60000 (23%)] avg_dstb_g_OT_loss: -938.5034 avg_dstb_remaining_f_loss: -603.1797 mu_2moment_loss: 89.8799 g_constraint_loss: 0.3441 W2_loss: 0.0668
# Train_Epoch: 1 [14000/60000 (23%)] avg_dstb_g_OT_loss: -938.5034 avg_dstb_remaining_f_loss: -603.1797 mu_2moment_loss: 89.8799 g_constraint_loss: 0.3441 W2_loss: 0.0668
# Train_Epoch: 1 [15000/60000 (25%)] avg_dstb_g_OT_loss: -864.8149 avg_dstb_remaining_f_loss: -705.0859 mu_2moment_loss: 113.3890 g_constraint_loss: 0.4050 W2_loss: 0.0718
# Train_Epoch: 1 [15000/60000 (25%)] avg_dstb_g_OT_loss: -864.8149 avg_dstb_remaining_f_loss: -705.0859 mu_2moment_loss: 113.3890 g_constraint_loss: 0.4050 W2_loss: 0.0718
# Train_Epoch: 1 [15000/60000 (25%)] avg_dstb_g_OT_loss: -864.8149 avg_dstb_remaining_f_loss: -705.0859 mu_2moment_loss: 113.3890 g_constraint_loss: 0.4050 W2_loss: 0.0718
# Train_Epoch: 1 [16000/60000 (27%)] avg_dstb_g_OT_loss: -873.4408 avg_dstb_remaining_f_loss: -804.6962 mu_2moment_loss: 143.8875 g_constraint_loss: 0.4140 W2_loss: 0.0972
# Train_Epoch: 1 [16000/60000 (27%)] avg_dstb_g_OT_loss: -873.4408 avg_dstb_remaining_f_loss: -804.6962 mu_2moment_loss: 143.8875 g_constraint_loss: 0.4140 W2_loss: 0.0972
# Train_Epoch: 1 [16000/60000 (27%)] avg_dstb_g_OT_loss: -873.4408 avg_dstb_remaining_f_loss: -804.6962 mu_2moment_loss: 143.8875 g_constraint_loss: 0.4140 W2_loss: 0.0972
# Train_Epoch: 1 [17000/60000 (28%)] avg_dstb_g_OT_loss: -905.4648 avg_dstb_remaining_f_loss: -887.9361 mu_2moment_loss: 178.2280 g_constraint_loss: 0.4400 W2_loss: 0.1457
# Train_Epoch: 1 [17000/60000 (28%)] avg_dstb_g_OT_loss: -905.4648 avg_dstb_remaining_f_loss: -887.9361 mu_2moment_loss: 178.2280 g_constraint_loss: 0.4400 W2_loss: 0.1457
# Train_Epoch: 1 [17000/60000 (28%)] avg_dstb_g_OT_loss: -905.4648 avg_dstb_remaining_f_loss: -887.9361 mu_2moment_loss: 178.2280 g_constraint_loss: 0.4400 W2_loss: 0.1457
# Train_Epoch: 1 [18000/60000 (30%)] avg_dstb_g_OT_loss: -856.5713 avg_dstb_remaining_f_loss: -966.5506 mu_2moment_loss: 215.2341 g_constraint_loss: 0.4969 W2_loss: 0.2459
# Train_Epoch: 1 [18000/60000 (30%)] avg_dstb_g_OT_loss: -856.5713 avg_dstb_remaining_f_loss: -966.5506 mu_2moment_loss: 215.2341 g_constraint_loss: 0.4969 W2_loss: 0.2459
# Train_Epoch: 1 [18000/60000 (30%)] avg_dstb_g_OT_loss: -856.5713 avg_dstb_remaining_f_loss: -966.5506 mu_2moment_loss: 215.2341 g_constraint_loss: 0.4969 W2_loss: 0.2459
# Train_Epoch: 1 [19000/60000 (32%)] avg_dstb_g_OT_loss: -918.4749 avg_dstb_remaining_f_loss: -1040.8958 mu_2moment_loss: 255.5511 g_constraint_loss: 0.5624 W2_loss: 0.4589
# Train_Epoch: 1 [19000/60000 (32%)] avg_dstb_g_OT_loss: -918.4749 avg_dstb_remaining_f_loss: -1040.8958 mu_2moment_loss: 255.5511 g_constraint_loss: 0.5624 W2_loss: 0.4589
# Train_Epoch: 1 [19000/60000 (32%)] avg_dstb_g_OT_loss: -918.4749 avg_dstb_remaining_f_loss: -1040.8958 mu_2moment_loss: 255.5511 g_constraint_loss: 0.5624 W2_loss: 0.4589
# Train_Epoch: 1 [20000/60000 (33%)] avg_dstb_g_OT_loss: -950.6881 avg_dstb_remaining_f_loss: -1095.7534 mu_2moment_loss: 298.5600 g_constraint_loss: 0.5435 W2_loss: 0.7199
# Train_Epoch: 1 [20000/60000 (33%)] avg_dstb_g_OT_loss: -950.6881 avg_dstb_remaining_f_loss: -1095.7534 mu_2moment_loss: 298.5600 g_constraint_loss: 0.5435 W2_loss: 0.7199
# Train_Epoch: 1 [20000/60000 (33%)] avg_dstb_g_OT_loss: -950.6881 avg_dstb_remaining_f_loss: -1095.7534 mu_2moment_loss: 298.5600 g_constraint_loss: 0.5435 W2_loss: 0.7199
# Train_Epoch: 1 [21000/60000 (35%)] avg_dstb_g_OT_loss: -935.1814 avg_dstb_remaining_f_loss: -1171.1661 mu_2moment_loss: 347.6050 g_constraint_loss: 0.5624 W2_loss: 0.8383
# Train_Epoch: 1 [21000/60000 (35%)] avg_dstb_g_OT_loss: -935.1814 avg_dstb_remaining_f_loss: -1171.1661 mu_2moment_loss: 347.6050 g_constraint_loss: 0.5624 W2_loss: 0.8383
# Train_Epoch: 1 [21000/60000 (35%)] avg_dstb_g_OT_loss: -935.1814 avg_dstb_remaining_f_loss: -1171.1661 mu_2moment_loss: 347.6050 g_constraint_loss: 0.5624 W2_loss: 0.8383
# Train_Epoch: 1 [31000/60000 (52%)] avg_dstb_g_OT_loss: -1190.2148 avg_dstb_remaining_f_loss: -1766.4981 mu_2moment_loss: 764.7429 g_constraint_loss: -0.1129 W2_loss: 3.9806
# Train_Epoch: 1 [31000/60000 (52%)] avg_dstb_g_OT_loss: -1190.2148 avg_dstb_remaining_f_loss: -1766.4981 mu_2moment_loss: 764.7429 g_constraint_loss: -0.1129 W2_loss: 3.9806
# Train_Epoch: 1 [32000/60000 (53%)] avg_dstb_g_OT_loss: -1313.7021 avg_dstb_remaining_f_loss: -1771.3328 mu_2moment_loss: 708.5597 g_constraint_loss: -0.3298 W2_loss: 3.5370
# Train_Epoch: 1 [32000/60000 (53%)] avg_dstb_g_OT_loss: -1313.7021 avg_dstb_remaining_f_loss: -1771.3328 mu_2moment_loss: 708.5597 g_constraint_loss: -0.3298 W2_loss: 3.5370
# Train_Epoch: 1 [32000/60000 (53%)] avg_dstb_g_OT_loss: -1313.7021 avg_dstb_remaining_f_loss: -1771.3328 mu_2moment_loss: 708.5597 g_constraint_loss: -0.3298 W2_loss: 3.5370
# Train_Epoch: 1 [33000/60000 (55%)] avg_dstb_g_OT_loss: -1557.2191 avg_dstb_remaining_f_loss: -1902.7290 mu_2moment_loss: 882.4085 g_constraint_loss: -0.3080 W2_loss: 4.5941
# Train_Epoch: 1 [33000/60000 (55%)] avg_dstb_g_OT_loss: -1557.2191 avg_dstb_remaining_f_loss: -1902.7290 mu_2moment_loss: 882.4085 g_constraint_loss: -0.3080 W2_loss: 4.5941
# Train_Epoch: 1 [33000/60000 (55%)] avg_dstb_g_OT_loss: -1557.2191 avg_dstb_remaining_f_loss: -1902.7290 mu_2moment_loss: 882.4085 g_constraint_loss: -0.3080 W2_loss: 4.5941
# Train_Epoch: 1 [34000/60000 (57%)] avg_dstb_g_OT_loss: -1511.0707 avg_dstb_remaining_f_loss: -1840.2144 mu_2moment_loss: 730.3171 g_constraint_loss: -0.6054 W2_loss: 3.1216
# Train_Epoch: 1 [34000/60000 (57%)] avg_dstb_g_OT_loss: -1511.0707 avg_dstb_remaining_f_loss: -1840.2144 mu_2moment_loss: 730.3171 g_constraint_loss: -0.6054 W2_loss: 3.1216
# Train_Epoch: 1 [34000/60000 (57%)] avg_dstb_g_OT_loss: -1511.0707 avg_dstb_remaining_f_loss: -1840.2144 mu_2moment_loss: 730.3171 g_constraint_loss: -0.6054 W2_loss: 3.1216
# Train_Epoch: 1 [35000/60000 (58%)] avg_dstb_g_OT_loss: -1329.1850 avg_dstb_remaining_f_loss: -2053.7118 mu_2moment_loss: 818.3785 g_constraint_loss: -0.6479 W2_loss: 3.5110
# Train_Epoch: 1 [35000/60000 (58%)] avg_dstb_g_OT_loss: -1329.1850 avg_dstb_remaining_f_loss: -2053.7118 mu_2moment_loss: 818.3785 g_constraint_loss: -0.6479 W2_loss: 3.5110
# Train_Epoch: 1 [35000/60000 (58%)] avg_dstb_g_OT_loss: -1329.1850 avg_dstb_remaining_f_loss: -2053.7118 mu_2moment_loss: 818.3785 g_constraint_loss: -0.6479 W2_loss: 3.5110
# Train_Epoch: 1 [36000/60000 (60%)] avg_dstb_g_OT_loss: -1518.9490 avg_dstb_remaining_f_loss: -2078.8313 mu_2moment_loss: 984.9423 g_constraint_loss: -0.6801 W2_loss: 4.5886
# Train_Epoch: 1 [36000/60000 (60%)] avg_dstb_g_OT_loss: -1518.9490 avg_dstb_remaining_f_loss: -2078.8313 mu_2moment_loss: 984.9423 g_constraint_loss: -0.6801 W2_loss: 4.5886
# Train_Epoch: 1 [36000/60000 (60%)] avg_dstb_g_OT_loss: -1518.9490 avg_dstb_remaining_f_loss: -2078.8313 mu_2moment_loss: 984.9423 g_constraint_loss: -0.6801 W2_loss: 4.5886
# Train_Epoch: 1 [37000/60000 (62%)] avg_dstb_g_OT_loss: -1474.4086 avg_dstb_remaining_f_loss: -2061.9113 mu_2moment_loss: 737.9506 g_constraint_loss: -0.9659 W2_loss: 2.1681
# Train_Epoch: 1 [37000/60000 (62%)] avg_dstb_g_OT_loss: -1474.4086 avg_dstb_remaining_f_loss: -2061.9113 mu_2moment_loss: 737.9506 g_constraint_loss: -0.9659 W2_loss: 2.1681
# Train_Epoch: 1 [37000/60000 (62%)] avg_dstb_g_OT_loss: -1474.4086 avg_dstb_remaining_f_loss: -2061.9113 mu_2moment_loss: 737.9506 g_constraint_loss: -0.9659 W2_loss: 2.1681
# Train_Epoch: 1 [38000/60000 (63%)] avg_dstb_g_OT_loss: -1465.5529 avg_dstb_remaining_f_loss: -2314.7667 mu_2moment_loss: 950.2797 g_constraint_loss: -1.0066 W2_loss: 4.0162
# Train_Epoch: 1 [38000/60000 (63%)] avg_dstb_g_OT_loss: -1465.5529 avg_dstb_remaining_f_loss: -2314.7667 mu_2moment_loss: 950.2797 g_constraint_loss: -1.0066 W2_loss: 4.0162
# Train_Epoch: 1 [38000/60000 (63%)] avg_dstb_g_OT_loss: -1465.5529 avg_dstb_remaining_f_loss: -2314.7667 mu_2moment_loss: 950.2797 g_constraint_loss: -1.0066 W2_loss: 4.0162
# Train_Epoch: 1 [39000/60000 (65%)] avg_dstb_g_OT_loss: -1605.5554 avg_dstb_remaining_f_loss: -2401.0854 mu_2moment_loss: 1119.8674 g_constraint_loss: -1.0597 W2_loss: 4.6297
# Train_Epoch: 1 [39000/60000 (65%)] avg_dstb_g_OT_loss: -1605.5554 avg_dstb_remaining_f_loss: -2401.0854 mu_2moment_loss: 1119.8674 g_constraint_loss: -1.0597 W2_loss: 4.6297
# Train_Epoch: 1 [39000/60000 (65%)] avg_dstb_g_OT_loss: -1605.5554 avg_dstb_remaining_f_loss: -2401.0854 mu_2moment_loss: 1119.8674 g_constraint_loss: -1.0597 W2_loss: 4.6297
# Train_Epoch: 1 [40000/60000 (67%)] avg_dstb_g_OT_loss: -1467.2750 avg_dstb_remaining_f_loss: -2234.7485 mu_2moment_loss: 822.2736 g_constraint_loss: -1.3404 W2_loss: 1.7757
# Train_Epoch: 1 [40000/60000 (67%)] avg_dstb_g_OT_loss: -1467.2750 avg_dstb_remaining_f_loss: -2234.7485 mu_2moment_loss: 822.2736 g_constraint_loss: -1.3404 W2_loss: 1.7757
# Train_Epoch: 1 [40000/60000 (67%)] avg_dstb_g_OT_loss: -1467.2750 avg_dstb_remaining_f_loss: -2234.7485 mu_2moment_loss: 822.2736 g_constraint_loss: -1.3404 W2_loss: 1.7757
# Train_Epoch: 1 [41000/60000 (68%)] avg_dstb_g_OT_loss: -1797.2230 avg_dstb_remaining_f_loss: -2338.7367 mu_2moment_loss: 906.7951 g_constraint_loss: -1.4808 W2_loss: 2.5565
# Train_Epoch: 1 [41000/60000 (68%)] avg_dstb_g_OT_loss: -1797.2230 avg_dstb_remaining_f_loss: -2338.7367 mu_2moment_loss: 906.7951 g_constraint_loss: -1.4808 W2_loss: 2.5565
# Train_Epoch: 1 [41000/60000 (68%)] avg_dstb_g_OT_loss: -1797.2230 avg_dstb_remaining_f_loss: -2338.7367 mu_2moment_loss: 906.7951 g_constraint_loss: -1.4808 W2_loss: 2.5565
# Train_Epoch: 1 [42000/60000 (70%)] avg_dstb_g_OT_loss: -1843.0956 avg_dstb_remaining_f_loss: -2662.2126 mu_2moment_loss: 1413.2306 g_constraint_loss: -1.4912 W2_loss: 6.2642
# Train_Epoch: 1 [42000/60000 (70%)] avg_dstb_g_OT_loss: -1843.0956 avg_dstb_remaining_f_loss: -2662.2126 mu_2moment_loss: 1413.2306 g_constraint_loss: -1.4912 W2_loss: 6.2642
# Train_Epoch: 1 [42000/60000 (70%)] avg_dstb_g_OT_loss: -1843.0956 avg_dstb_remaining_f_loss: -2662.2126 mu_2moment_loss: 1413.2306 g_constraint_loss: -1.4912 W2_loss: 6.2642
# Train_Epoch: 1 [43000/60000 (72%)] avg_dstb_g_OT_loss: -1848.3067 avg_dstb_remaining_f_loss: -2473.8099 mu_2moment_loss: 1230.0418 g_constraint_loss: -1.6927 W2_loss: 3.3996
# Train_Epoch: 1 [43000/60000 (72%)] avg_dstb_g_OT_loss: -1848.3067 avg_dstb_remaining_f_loss: -2473.8099 mu_2moment_loss: 1230.0418 g_constraint_loss: -1.6927 W2_loss: 3.3996
# Train_Epoch: 1 [43000/60000 (72%)] avg_dstb_g_OT_loss: -1848.3067 avg_dstb_remaining_f_loss: -2473.8099 mu_2moment_loss: 1230.0418 g_constraint_loss: -1.6927 W2_loss: 3.3996
# Train_Epoch: 1 [44000/60000 (73%)] avg_dstb_g_OT_loss: -1979.1743 avg_dstb_remaining_f_loss: -2378.5684 mu_2moment_loss: 1024.6750 g_constraint_loss: -1.8806 W2_loss: 1.1072
# Train_Epoch: 1 [44000/60000 (73%)] avg_dstb_g_OT_loss: -1979.1743 avg_dstb_remaining_f_loss: -2378.5684 mu_2moment_loss: 1024.6750 g_constraint_loss: -1.8806 W2_loss: 1.1072
# Train_Epoch: 1 [44000/60000 (73%)] avg_dstb_g_OT_loss: -1979.1743 avg_dstb_remaining_f_loss: -2378.5684 mu_2moment_loss: 1024.6750 g_constraint_loss: -1.8806 W2_loss: 1.1072
# Train_Epoch: 1 [45000/60000 (75%)] avg_dstb_g_OT_loss: -1846.3474 avg_dstb_remaining_f_loss: -2619.9608 mu_2moment_loss: 1248.8182 g_constraint_loss: -2.0127 W2_loss: 1.7370
# Train_Epoch: 1 [45000/60000 (75%)] avg_dstb_g_OT_loss: -1846.3474 avg_dstb_remaining_f_loss: -2619.9608 mu_2moment_loss: 1248.8182 g_constraint_loss: -2.0127 W2_loss: 1.7370
# Train_Epoch: 1 [45000/60000 (75%)] avg_dstb_g_OT_loss: -1846.3474 avg_dstb_remaining_f_loss: -2619.9608 mu_2moment_loss: 1248.8182 g_constraint_loss: -2.0127 W2_loss: 1.7370
# Train_Epoch: 1 [46000/60000 (77%)] avg_dstb_g_OT_loss: -2279.3839 avg_dstb_remaining_f_loss: -2887.0556 mu_2moment_loss: 1686.1322 g_constraint_loss: -2.1490 W2_loss: 5.1295
# Train_Epoch: 1 [46000/60000 (77%)] avg_dstb_g_OT_loss: -2279.3839 avg_dstb_remaining_f_loss: -2887.0556 mu_2moment_loss: 1686.1322 g_constraint_loss: -2.1490 W2_loss: 5.1295
# Train_Epoch: 1 [46000/60000 (77%)] avg_dstb_g_OT_loss: -2279.3839 avg_dstb_remaining_f_loss: -2887.0556 mu_2moment_loss: 1686.1322 g_constraint_loss: -2.1490 W2_loss: 5.1295
# Train_Epoch: 1 [47000/60000 (78%)] avg_dstb_g_OT_loss: -2343.7913 avg_dstb_remaining_f_loss: -2805.2960 mu_2moment_loss: 1560.3852 g_constraint_loss: -2.3020 W2_loss: 4.0533
# Train_Epoch: 1 [47000/60000 (78%)] avg_dstb_g_OT_loss: -2343.7913 avg_dstb_remaining_f_loss: -2805.2960 mu_2moment_loss: 1560.3852 g_constraint_loss: -2.3020 W2_loss: 4.0533
# Train_Epoch: 1 [47000/60000 (78%)] avg_dstb_g_OT_loss: -2343.7913 avg_dstb_remaining_f_loss: -2805.2960 mu_2moment_loss: 1560.3852 g_constraint_loss: -2.3020 W2_loss: 4.0533
# Train_Epoch: 1 [48000/60000 (80%)] avg_dstb_g_OT_loss: -2448.1527 avg_dstb_remaining_f_loss: -2804.8541 mu_2moment_loss: 1389.7163 g_constraint_loss: -2.4368 W2_loss: 1.3018
# Train_Epoch: 1 [48000/60000 (80%)] avg_dstb_g_OT_loss: -2448.1527 avg_dstb_remaining_f_loss: -2804.8541 mu_2moment_loss: 1389.7163 g_constraint_loss: -2.4368 W2_loss: 1.3018
# Train_Epoch: 1 [48000/60000 (80%)] avg_dstb_g_OT_loss: -2448.1527 avg_dstb_remaining_f_loss: -2804.8541 mu_2moment_loss: 1389.7163 g_constraint_loss: -2.4368 W2_loss: 1.3018
# Train_Epoch: 1 [49000/60000 (82%)] avg_dstb_g_OT_loss: -2328.6172 avg_dstb_remaining_f_loss: -2931.1965 mu_2moment_loss: 1614.4218 g_constraint_loss: -2.6212 W2_loss: 1.4338
# Train_Epoch: 1 [49000/60000 (82%)] avg_dstb_g_OT_loss: -2328.6172 avg_dstb_remaining_f_loss: -2931.1965 mu_2moment_loss: 1614.4218 g_constraint_loss: -2.6212 W2_loss: 1.4338
# Train_Epoch: 1 [49000/60000 (82%)] avg_dstb_g_OT_loss: -2328.6172 avg_dstb_remaining_f_loss: -2931.1965 mu_2moment_loss: 1614.4218 g_constraint_loss: -2.6212 W2_loss: 1.4338
# Train_Epoch: 1 [50000/60000 (83%)] avg_dstb_g_OT_loss: -2321.8070 avg_dstb_remaining_f_loss: -3100.2150 mu_2moment_loss: 1858.1312 g_constraint_loss: -2.8347 W2_loss: 2.4735
# Train_Epoch: 1 [50000/60000 (83%)] avg_dstb_g_OT_loss: -2321.8070 avg_dstb_remaining_f_loss: -3100.2150 mu_2moment_loss: 1858.1312 g_constraint_loss: -2.8347 W2_loss: 2.4735
# Train_Epoch: 1 [50000/60000 (83%)] avg_dstb_g_OT_loss: -2321.8070 avg_dstb_remaining_f_loss: -3100.2150 mu_2moment_loss: 1858.1312 g_constraint_loss: -2.8347 W2_loss: 2.4735
# Train_Epoch: 1 [51000/60000 (85%)] avg_dstb_g_OT_loss: -2551.6111 avg_dstb_remaining_f_loss: -3035.4621 mu_2moment_loss: 1651.3320 g_constraint_loss: -2.9761 W2_loss: 2.7305
# Train_Epoch: 1 [51000/60000 (85%)] avg_dstb_g_OT_loss: -2551.6111 avg_dstb_remaining_f_loss: -3035.4621 mu_2moment_loss: 1651.3320 g_constraint_loss: -2.9761 W2_loss: 2.7305
# Train_Epoch: 1 [51000/60000 (85%)] avg_dstb_g_OT_loss: -2551.6111 avg_dstb_remaining_f_loss: -3035.4621 mu_2moment_loss: 1651.3320 g_constraint_loss: -2.9761 W2_loss: 2.7305
# Train_Epoch: 1 [52000/60000 (87%)] avg_dstb_g_OT_loss: -2426.0161 avg_dstb_remaining_f_loss: -3048.2872 mu_2moment_loss: 1620.3090 g_constraint_loss: -3.1331 W2_loss: 5.0812
# Train_Epoch: 1 [52000/60000 (87%)] avg_dstb_g_OT_loss: -2426.0161 avg_dstb_remaining_f_loss: -3048.2872 mu_2moment_loss: 1620.3090 g_constraint_loss: -3.1331 W2_loss: 5.0812
# Train_Epoch: 1 [52000/60000 (87%)] avg_dstb_g_OT_loss: -2426.0161 avg_dstb_remaining_f_loss: -3048.2872 mu_2moment_loss: 1620.3090 g_constraint_loss: -3.1331 W2_loss: 5.0812
# Train_Epoch: 1 [53000/60000 (88%)] avg_dstb_g_OT_loss: -2853.6749 avg_dstb_remaining_f_loss: -3331.9831 mu_2moment_loss: 1979.7639 g_constraint_loss: -3.3604 W2_loss: 9.5474
# Train_Epoch: 1 [53000/60000 (88%)] avg_dstb_g_OT_loss: -2853.6749 avg_dstb_remaining_f_loss: -3331.9831 mu_2moment_loss: 1979.7639 g_constraint_loss: -3.3604 W2_loss: 9.5474
# Train_Epoch: 1 [53000/60000 (88%)] avg_dstb_g_OT_loss: -2853.6749 avg_dstb_remaining_f_loss: -3331.9831 mu_2moment_loss: 1979.7639 g_constraint_loss: -3.3604 W2_loss: 9.5474
# Train_Epoch: 1 [54000/60000 (90%)] avg_dstb_g_OT_loss: -2833.6594 avg_dstb_remaining_f_loss: -3238.4279 mu_2moment_loss: 2032.6039 g_constraint_loss: -3.5317 W2_loss: 11.5946
# Train_Epoch: 1 [54000/60000 (90%)] avg_dstb_g_OT_loss: -2833.6594 avg_dstb_remaining_f_loss: -3238.4279 mu_2moment_loss: 2032.6039 g_constraint_loss: -3.5317 W2_loss: 11.5946
# Train_Epoch: 1 [54000/60000 (90%)] avg_dstb_g_OT_loss: -2833.6594 avg_dstb_remaining_f_loss: -3238.4279 mu_2moment_loss: 2032.6039 g_constraint_loss: -3.5317 W2_loss: 11.5946
# Train_Epoch: 1 [55000/60000 (92%)] avg_dstb_g_OT_loss: -2769.0563 avg_dstb_remaining_f_loss: -3197.5416 mu_2moment_loss: 1817.4729 g_constraint_loss: -3.6232 W2_loss: 10.2387
# Train_Epoch: 1 [55000/60000 (92%)] avg_dstb_g_OT_loss: -2769.0563 avg_dstb_remaining_f_loss: -3197.5416 mu_2moment_loss: 1817.4729 g_constraint_loss: -3.6232 W2_loss: 10.2387
# Train_Epoch: 1 [55000/60000 (92%)] avg_dstb_g_OT_loss: -2769.0563 avg_dstb_remaining_f_loss: -3197.5416 mu_2moment_loss: 1817.4729 g_constraint_loss: -3.6232 W2_loss: 10.2387
# Train_Epoch: 1 [56000/60000 (93%)] avg_dstb_g_OT_loss: -2868.6024 avg_dstb_remaining_f_loss: -3423.2689 mu_2moment_loss: 2084.6906 g_constraint_loss: -3.8490 W2_loss: 8.6743
# Train_Epoch: 1 [56000/60000 (93%)] avg_dstb_g_OT_loss: -2868.6024 avg_dstb_remaining_f_loss: -3423.2689 mu_2moment_loss: 2084.6906 g_constraint_loss: -3.8490 W2_loss: 8.6743
# Train_Epoch: 1 [56000/60000 (93%)] avg_dstb_g_OT_loss: -2868.6024 avg_dstb_remaining_f_loss: -3423.2689 mu_2moment_loss: 2084.6906 g_constraint_loss: -3.8490 W2_loss: 8.6743
# Train_Epoch: 1 [57000/60000 (95%)] avg_dstb_g_OT_loss: -2977.9934 avg_dstb_remaining_f_loss: -3566.4484 mu_2moment_loss: 2343.5275 g_constraint_loss: -4.1241 W2_loss: 7.0253
# Train_Epoch: 1 [57000/60000 (95%)] avg_dstb_g_OT_loss: -2977.9934 avg_dstb_remaining_f_loss: -3566.4484 mu_2moment_loss: 2343.5275 g_constraint_loss: -4.1241 W2_loss: 7.0253
# Train_Epoch: 1 [57000/60000 (95%)] avg_dstb_g_OT_loss: -2977.9934 avg_dstb_remaining_f_loss: -3566.4484 mu_2moment_loss: 2343.5275 g_constraint_loss: -4.1241 W2_loss: 7.0253
# Train_Epoch: 1 [58000/60000 (97%)] avg_dstb_g_OT_loss: -3183.7222 avg_dstb_remaining_f_loss: -3408.0970 mu_2moment_loss: 2166.3572 g_constraint_loss: -4.2131 W2_loss: 9.9958
# Train_Epoch: 1 [58000/60000 (97%)] avg_dstb_g_OT_loss: -3183.7222 avg_dstb_remaining_f_loss: -3408.0970 mu_2moment_loss: 2166.3572 g_constraint_loss: -4.2131 W2_loss: 9.9958
# Train_Epoch: 2 [3000/60000 (5%)] avg_dstb_g_OT_loss: -3399.7421 avg_dstb_remaining_f_loss: -3947.6735 mu_2moment_loss: 2760.8330 g_constraint_loss: -5.1115 W2_loss: 22.5608
# Train_Epoch: 2 [3000/60000 (5%)] avg_dstb_g_OT_loss: -3399.7421 avg_dstb_remaining_f_loss: -3947.6735 mu_2moment_loss: 2760.8330 g_constraint_loss: -5.1115 W2_loss: 22.5608
# Train_Epoch: 2 [4000/60000 (7%)] avg_dstb_g_OT_loss: -3969.3156 avg_dstb_remaining_f_loss: -3910.2692 mu_2moment_loss: 3011.5256 g_constraint_loss: -5.2883 W2_loss: 23.2511
# Train_Epoch: 2 [4000/60000 (7%)] avg_dstb_g_OT_loss: -3969.3156 avg_dstb_remaining_f_loss: -3910.2692 mu_2moment_loss: 3011.5256 g_constraint_loss: -5.2883 W2_loss: 23.2511
# Train_Epoch: 2 [4000/60000 (7%)] avg_dstb_g_OT_loss: -3969.3156 avg_dstb_remaining_f_loss: -3910.2692 mu_2moment_loss: 3011.5256 g_constraint_loss: -5.2883 W2_loss: 23.2511
# Train_Epoch: 2 [5000/60000 (8%)] avg_dstb_g_OT_loss: -3321.1479 avg_dstb_remaining_f_loss: -4003.8178 mu_2moment_loss: 2776.5488 g_constraint_loss: -5.2283 W2_loss: 29.3752
# Train_Epoch: 2 [5000/60000 (8%)] avg_dstb_g_OT_loss: -3321.1479 avg_dstb_remaining_f_loss: -4003.8178 mu_2moment_loss: 2776.5488 g_constraint_loss: -5.2283 W2_loss: 29.3752
# Train_Epoch: 2 [5000/60000 (8%)] avg_dstb_g_OT_loss: -3321.1479 avg_dstb_remaining_f_loss: -4003.8178 mu_2moment_loss: 2776.5488 g_constraint_loss: -5.2283 W2_loss: 29.3752
# Train_Epoch: 2 [6000/60000 (10%)] avg_dstb_g_OT_loss: -3481.2959 avg_dstb_remaining_f_loss: -4201.2927 mu_2moment_loss: 3122.7336 g_constraint_loss: -5.4391 W2_loss: 23.2168
# Train_Epoch: 2 [6000/60000 (10%)] avg_dstb_g_OT_loss: -3481.2959 avg_dstb_remaining_f_loss: -4201.2927 mu_2moment_loss: 3122.7336 g_constraint_loss: -5.4391 W2_loss: 23.2168
# Train_Epoch: 2 [6000/60000 (10%)] avg_dstb_g_OT_loss: -3481.2959 avg_dstb_remaining_f_loss: -4201.2927 mu_2moment_loss: 3122.7336 g_constraint_loss: -5.4391 W2_loss: 23.2168
# Train_Epoch: 2 [7000/60000 (12%)] avg_dstb_g_OT_loss: -3501.1625 avg_dstb_remaining_f_loss: -4115.5249 mu_2moment_loss: 3155.4238 g_constraint_loss: -5.5263 W2_loss: 27.3375
# Train_Epoch: 2 [7000/60000 (12%)] avg_dstb_g_OT_loss: -3501.1625 avg_dstb_remaining_f_loss: -4115.5249 mu_2moment_loss: 3155.4238 g_constraint_loss: -5.5263 W2_loss: 27.3375
# Train_Epoch: 2 [7000/60000 (12%)] avg_dstb_g_OT_loss: -3501.1625 avg_dstb_remaining_f_loss: -4115.5249 mu_2moment_loss: 3155.4238 g_constraint_loss: -5.5263 W2_loss: 27.3375
# Train_Epoch: 2 [26000/60000 (43%)] avg_dstb_g_OT_loss: -4681.7030 avg_dstb_remaining_f_loss: -5148.3484 mu_2moment_loss: 4504.1547 g_constraint_loss: -7.5708 W2_loss: 49.8831
# Train_Epoch: 2 [26000/60000 (43%)] avg_dstb_g_OT_loss: -4681.7030 avg_dstb_remaining_f_loss: -5148.3484 mu_2moment_loss: 4504.1547 g_constraint_loss: -7.5708 W2_loss: 49.8831
# Train_Epoch: 2 [26000/60000 (43%)] avg_dstb_g_OT_loss: -4681.7030 avg_dstb_remaining_f_loss: -5148.3484 mu_2moment_loss: 4504.1547 g_constraint_loss: -7.5708 W2_loss: 49.8831
# Train_Epoch: 2 [27000/60000 (45%)] avg_dstb_g_OT_loss: -4765.7209 avg_dstb_remaining_f_loss: -5219.4166 mu_2moment_loss: 4571.2437 g_constraint_loss: -7.5291 W2_loss: 43.2446
# Train_Epoch: 2 [27000/60000 (45%)] avg_dstb_g_OT_loss: -4765.7209 avg_dstb_remaining_f_loss: -5219.4166 mu_2moment_loss: 4571.2437 g_constraint_loss: -7.5291 W2_loss: 43.2446
# Train_Epoch: 2 [27000/60000 (45%)] avg_dstb_g_OT_loss: -4765.7209 avg_dstb_remaining_f_loss: -5219.4166 mu_2moment_loss: 4571.2437 g_constraint_loss: -7.5291 W2_loss: 43.2446
# Train_Epoch: 2 [28000/60000 (47%)] avg_dstb_g_OT_loss: -5012.0655 avg_dstb_remaining_f_loss: -5234.2018 mu_2moment_loss: 4558.6500 g_constraint_loss: -7.5833 W2_loss: 46.9964
# Train_Epoch: 2 [28000/60000 (47%)] avg_dstb_g_OT_loss: -5012.0655 avg_dstb_remaining_f_loss: -5234.2018 mu_2moment_loss: 4558.6500 g_constraint_loss: -7.5833 W2_loss: 46.9964
# Train_Epoch: 2 [28000/60000 (47%)] avg_dstb_g_OT_loss: -5012.0655 avg_dstb_remaining_f_loss: -5234.2018 mu_2moment_loss: 4558.6500 g_constraint_loss: -7.5833 W2_loss: 46.9964
# Train_Epoch: 2 [29000/60000 (48%)] avg_dstb_g_OT_loss: -4741.3161 avg_dstb_remaining_f_loss: -5242.9260 mu_2moment_loss: 4659.5629 g_constraint_loss: -7.6015 W2_loss: 38.7068
# Train_Epoch: 2 [29000/60000 (48%)] avg_dstb_g_OT_loss: -4741.3161 avg_dstb_remaining_f_loss: -5242.9260 mu_2moment_loss: 4659.5629 g_constraint_loss: -7.6015 W2_loss: 38.7068
# Train_Epoch: 2 [29000/60000 (48%)] avg_dstb_g_OT_loss: -4741.3161 avg_dstb_remaining_f_loss: -5242.9260 mu_2moment_loss: 4659.5629 g_constraint_loss: -7.6015 W2_loss: 38.7068
# Train_Epoch: 2 [30000/60000 (50%)] avg_dstb_g_OT_loss: -5061.8032 avg_dstb_remaining_f_loss: -5240.8257 mu_2moment_loss: 4600.1234 g_constraint_loss: -7.7012 W2_loss: 48.8804
# Train_Epoch: 2 [30000/60000 (50%)] avg_dstb_g_OT_loss: -5061.8032 avg_dstb_remaining_f_loss: -5240.8257 mu_2moment_loss: 4600.1234 g_constraint_loss: -7.7012 W2_loss: 48.8804
# Train_Epoch: 2 [30000/60000 (50%)] avg_dstb_g_OT_loss: -5061.8032 avg_dstb_remaining_f_loss: -5240.8257 mu_2moment_loss: 4600.1234 g_constraint_loss: -7.7012 W2_loss: 48.8804
# Train_Epoch: 2 [31000/60000 (52%)] avg_dstb_g_OT_loss: -5085.8735 avg_dstb_remaining_f_loss: -5190.2141 mu_2moment_loss: 4662.7516 g_constraint_loss: -7.8549 W2_loss: 49.5403
# Train_Epoch: 2 [31000/60000 (52%)] avg_dstb_g_OT_loss: -5085.8735 avg_dstb_remaining_f_loss: -5190.2141 mu_2moment_loss: 4662.7516 g_constraint_loss: -7.8549 W2_loss: 49.5403
# ...
# Train_Epoch: 3 [2000/60000 (3%)] avg_dstb_g_OT_loss: -5910.1770 avg_dstb_remaining_f_loss: -5739.0533 mu_2moment_loss: 5508.0309 g_constraint_loss: -7.8549 W2_loss: 57.7661
# Train_Epoch: 3 [2000/60000 (3%)] avg_dstb_g_OT_loss: -5910.1770 avg_dstb_remaining_f_loss: -5739.0533 mu_2moment_loss: 5508.0309 g_constraint_loss: -7.8549 W2_loss: 57.7661
# Train_Epoch: 3 [3000/60000 (5%)] avg_dstb_g_OT_loss: -5855.4282 avg_dstb_remaining_f_loss: -6128.9829 mu_2moment_loss: 5701.2012 g_constraint_loss: -7.9330 W2_loss: 74.6733
# Train_Epoch: 3 [3000/60000 (5%)] avg_dstb_g_OT_loss: -5855.4282 avg_dstb_remaining_f_loss: -6128.9829 mu_2moment_loss: 5701.2012 g_constraint_loss: -7.9330 W2_loss: 74.6733
# Train_Epoch: 3 [3000/60000 (5%)] avg_dstb_g_OT_loss: -5855.4282 avg_dstb_remaining_f_loss: -6128.9829 mu_2moment_loss: 5701.2012 g_constraint_loss: -7.9330 W2_loss: 74.6733
# Train_Epoch: 3 [4000/60000 (7%)] avg_dstb_g_OT_loss: -5819.4209 avg_dstb_remaining_f_loss: -6410.8613 mu_2moment_loss: 5842.0316 g_constraint_loss: -8.1432 W2_loss: 73.7982
# Train_Epoch: 3 [4000/60000 (7%)] avg_dstb_g_OT_loss: -5819.4209 avg_dstb_remaining_f_loss: -6410.8613 mu_2moment_loss: 5842.0316 g_constraint_loss: -8.1432 W2_loss: 73.7982
# Train_Epoch: 3 [4000/60000 (7%)] avg_dstb_g_OT_loss: -5819.4209 avg_dstb_remaining_f_loss: -6410.8613 mu_2moment_loss: 5842.0316 g_constraint_loss: -8.1432 W2_loss: 73.7982
# Train_Epoch: 3 [5000/60000 (8%)] avg_dstb_g_OT_loss: -5975.6067 avg_dstb_remaining_f_loss: -6044.5693 mu_2moment_loss: 5814.6875 g_constraint_loss: -8.0292 W2_loss: 67.3031
# Train_Epoch: 3 [5000/60000 (8%)] avg_dstb_g_OT_loss: -5975.6067 avg_dstb_remaining_f_loss: -6044.5693 mu_2moment_loss: 5814.6875 g_constraint_loss: -8.0292 W2_loss: 67.3031
# Train_Epoch: 3 [5000/60000 (8%)] avg_dstb_g_OT_loss: -5975.6067 avg_dstb_remaining_f_loss: -6044.5693 mu_2moment_loss: 5814.6875 g_constraint_loss: -8.0292 W2_loss: 67.3031
# Train_Epoch: 3 [10000/60000 (17%)] avg_dstb_g_OT_loss: -6188.7578 avg_dstb_remaining_f_loss: -5929.1221 mu_2moment_loss: 5782.9457 g_constraint_loss: -7.7031 W2_loss: 74.8171
# Train_Epoch: 3 [10000/60000 (17%)] avg_dstb_g_OT_loss: -6188.7578 avg_dstb_remaining_f_loss: -5929.1221 mu_2moment_loss: 5782.9457 g_constraint_loss: -7.7031 W2_loss: 74.8171
# Train_Epoch: 3 [11000/60000 (18%)] avg_dstb_g_OT_loss: -5755.1763 avg_dstb_remaining_f_loss: -5921.4806 mu_2moment_loss: 5545.1609 g_constraint_loss: -7.5215 W2_loss: 76.8282
# Train_Epoch: 3 [11000/60000 (18%)] avg_dstb_g_OT_loss: -5755.1763 avg_dstb_remaining_f_loss: -5921.4806 mu_2moment_loss: 5545.1609 g_constraint_loss: -7.5215 W2_loss: 76.8282
# Train_Epoch: 3 [11000/60000 (18%)] avg_dstb_g_OT_loss: -5755.1763 avg_dstb_remaining_f_loss: -5921.4806 mu_2moment_loss: 5545.1609 g_constraint_loss: -7.5215 W2_loss: 76.8282
# Train_Epoch: 3 [12000/60000 (20%)] avg_dstb_g_OT_loss: -5899.6904 avg_dstb_remaining_f_loss: -5732.7503 mu_2moment_loss: 5584.8164 g_constraint_loss: -7.5166 W2_loss: 79.5260
# Train_Epoch: 3 [12000/60000 (20%)] avg_dstb_g_OT_loss: -5899.6904 avg_dstb_remaining_f_loss: -5732.7503 mu_2moment_loss: 5584.8164 g_constraint_loss: -7.5166 W2_loss: 79.5260
# Train_Epoch: 3 [12000/60000 (20%)] avg_dstb_g_OT_loss: -5899.6904 avg_dstb_remaining_f_loss: -5732.7503 mu_2moment_loss: 5584.8164 g_constraint_loss: -7.5166 W2_loss: 79.5260
# Train_Epoch: 3 [13000/60000 (22%)] avg_dstb_g_OT_loss: -6196.5821 avg_dstb_remaining_f_loss: -5899.2807 mu_2moment_loss: 5629.1055 g_constraint_loss: -7.5989 W2_loss: 84.2140
# Train_Epoch: 3 [13000/60000 (22%)] avg_dstb_g_OT_loss: -6196.5821 avg_dstb_remaining_f_loss: -5899.2807 mu_2moment_loss: 5629.1055 g_constraint_loss: -7.5989 W2_loss: 84.2140
# Train_Epoch: 3 [13000/60000 (22%)] avg_dstb_g_OT_loss: -6196.5821 avg_dstb_remaining_f_loss: -5899.2807 mu_2moment_loss: 5629.1055 g_constraint_loss: -7.5989 W2_loss: 84.2140
# Train_Epoch: 3 [14000/60000 (23%)] avg_dstb_g_OT_loss: -5526.1094 avg_dstb_remaining_f_loss: -6251.1297 mu_2moment_loss: 5965.6719 g_constraint_loss: -7.7468 W2_loss: 74.7014
# Train_Epoch: 3 [14000/60000 (23%)] avg_dstb_g_OT_loss: -5526.1094 avg_dstb_remaining_f_loss: -6251.1297 mu_2moment_loss: 5965.6719 g_constraint_loss: -7.7468 W2_loss: 74.7014
# Train_Epoch: 3 [14000/60000 (23%)] avg_dstb_g_OT_loss: -5526.1094 avg_dstb_remaining_f_loss: -6251.1297 mu_2moment_loss: 5965.6719 g_constraint_loss: -7.7468 W2_loss: 74.7014
# Train_Epoch: 3 [15000/60000 (25%)] avg_dstb_g_OT_loss: -5968.3979 avg_dstb_remaining_f_loss: -5853.0481 mu_2moment_loss: 5610.5719 g_constraint_loss: -7.4568 W2_loss: 73.6349
# Train_Epoch: 3 [15000/60000 (25%)] avg_dstb_g_OT_loss: -5968.3979 avg_dstb_remaining_f_loss: -5853.0481 mu_2moment_loss: 5610.5719 g_constraint_loss: -7.4568 W2_loss: 73.6349
# Train_Epoch: 3 [15000/60000 (25%)] avg_dstb_g_OT_loss: -5968.3979 avg_dstb_remaining_f_loss: -5853.0481 mu_2moment_loss: 5610.5719 g_constraint_loss: -7.4568 W2_loss: 73.6349
# Train_Epoch: 3 [16000/60000 (27%)] avg_dstb_g_OT_loss: -6193.2537 avg_dstb_remaining_f_loss: -5804.7847 mu_2moment_loss: 5652.5254 g_constraint_loss: -7.4958 W2_loss: 82.3907
# Train_Epoch: 3 [16000/60000 (27%)] avg_dstb_g_OT_loss: -6193.2537 avg_dstb_remaining_f_loss: -5804.7847 mu_2moment_loss: 5652.5254 g_constraint_loss: -7.4958 W2_loss: 82.3907
# Train_Epoch: 3 [16000/60000 (27%)] avg_dstb_g_OT_loss: -6193.2537 avg_dstb_remaining_f_loss: -5804.7847 mu_2moment_loss: 5652.5254 g_constraint_loss: -7.4958 W2_loss: 82.3907
# Train_Epoch: 3 [17000/60000 (28%)] avg_dstb_g_OT_loss: -5630.6175 avg_dstb_remaining_f_loss: -6190.2403 mu_2moment_loss: 5822.2484 g_constraint_loss: -7.5404 W2_loss: 71.6625
# Train_Epoch: 3 [17000/60000 (28%)] avg_dstb_g_OT_loss: -5630.6175 avg_dstb_remaining_f_loss: -6190.2403 mu_2moment_loss: 5822.2484 g_constraint_loss: -7.5404 W2_loss: 71.6625
# Train_Epoch: 3 [17000/60000 (28%)] avg_dstb_g_OT_loss: -5630.6175 avg_dstb_remaining_f_loss: -6190.2403 mu_2moment_loss: 5822.2484 g_constraint_loss: -7.5404 W2_loss: 71.6625
# Train_Epoch: 3 [18000/60000 (30%)] avg_dstb_g_OT_loss: -6123.9136 avg_dstb_remaining_f_loss: -6345.9409 mu_2moment_loss: 5940.3055 g_constraint_loss: -7.6575 W2_loss: 64.9958
# Train_Epoch: 3 [18000/60000 (30%)] avg_dstb_g_OT_loss: -6123.9136 avg_dstb_remaining_f_loss: -6345.9409 mu_2moment_loss: 5940.3055 g_constraint_loss: -7.6575 W2_loss: 64.9958
# Train_Epoch: 3 [18000/60000 (30%)] avg_dstb_g_OT_loss: -6123.9136 avg_dstb_remaining_f_loss: -6345.9409 mu_2moment_loss: 5940.3055 g_constraint_loss: -7.6575 W2_loss: 64.9958
# Train_Epoch: 3 [19000/60000 (32%)] avg_dstb_g_OT_loss: -5892.8893 avg_dstb_remaining_f_loss: -6147.7497 mu_2moment_loss: 5727.2547 g_constraint_loss: -7.5718 W2_loss: 76.4762
# Train_Epoch: 3 [19000/60000 (32%)] avg_dstb_g_OT_loss: -5892.8893 avg_dstb_remaining_f_loss: -6147.7497 mu_2moment_loss: 5727.2547 g_constraint_loss: -7.5718 W2_loss: 76.4762
# Train_Epoch: 3 [19000/60000 (32%)] avg_dstb_g_OT_loss: -5892.8893 avg_dstb_remaining_f_loss: -6147.7497 mu_2moment_loss: 5727.2547 g_constraint_loss: -7.5718 W2_loss: 76.4762
# Train_Epoch: 3 [20000/60000 (33%)] avg_dstb_g_OT_loss: -5632.7032 avg_dstb_remaining_f_loss: -6101.0965 mu_2moment_loss: 5739.8906 g_constraint_loss: -7.5516 W2_loss: 94.5788
# Train_Epoch: 3 [20000/60000 (33%)] avg_dstb_g_OT_loss: -5632.7032 avg_dstb_remaining_f_loss: -6101.0965 mu_2moment_loss: 5739.8906 g_constraint_loss: -7.5516 W2_loss: 94.5788
# Train_Epoch: 3 [20000/60000 (33%)] avg_dstb_g_OT_loss: -5632.7032 avg_dstb_remaining_f_loss: -6101.0965 mu_2moment_loss: 5739.8906 g_constraint_loss: -7.5516 W2_loss: 94.5788
# Train_Epoch: 3 [21000/60000 (35%)] avg_dstb_g_OT_loss: -5662.8623 avg_dstb_remaining_f_loss: -6381.7128 mu_2moment_loss: 5955.8789 g_constraint_loss: -7.4575 W2_loss: 82.2009
# Train_Epoch: 3 [21000/60000 (35%)] avg_dstb_g_OT_loss: -5662.8623 avg_dstb_remaining_f_loss: -6381.7128 mu_2moment_loss: 5955.8789 g_constraint_loss: -7.4575 W2_loss: 82.2009
# Train_Epoch: 3 [21000/60000 (35%)] avg_dstb_g_OT_loss: -5662.8623 avg_dstb_remaining_f_loss: -6381.7128 mu_2moment_loss: 5955.8789 g_constraint_loss: -7.4575 W2_loss: 82.2009
# Train_Epoch: 3 [22000/60000 (37%)] avg_dstb_g_OT_loss: -6108.7152 avg_dstb_remaining_f_loss: -6115.9300 mu_2moment_loss: 5863.6289 g_constraint_loss: -7.4384 W2_loss: 72.4575
# Train_Epoch: 3 [22000/60000 (37%)] avg_dstb_g_OT_loss: -6108.7152 avg_dstb_remaining_f_loss: -6115.9300 mu_2moment_loss: 5863.6289 g_constraint_loss: -7.4384 W2_loss: 72.4575
# Train_Epoch: 3 [22000/60000 (37%)] avg_dstb_g_OT_loss: -6108.7152 avg_dstb_remaining_f_loss: -6115.9300 mu_2moment_loss: 5863.6289 g_constraint_loss: -7.4384 W2_loss: 72.4575
# Train_Epoch: 3 [23000/60000 (38%)] avg_dstb_g_OT_loss: -5885.5448 avg_dstb_remaining_f_loss: -5839.7858 mu_2moment_loss: 5304.8590 g_constraint_loss: -7.1010 W2_loss: 72.2637
# Train_Epoch: 3 [23000/60000 (38%)] avg_dstb_g_OT_loss: -5885.5448 avg_dstb_remaining_f_loss: -5839.7858 mu_2moment_loss: 5304.8590 g_constraint_loss: -7.1010 W2_loss: 72.2637
# Train_Epoch: 3 [23000/60000 (38%)] avg_dstb_g_OT_loss: -5885.5448 avg_dstb_remaining_f_loss: -5839.7858 mu_2moment_loss: 5304.8590 g_constraint_loss: -7.1010 W2_loss: 72.2637
# Train_Epoch: 3 [24000/60000 (40%)] avg_dstb_g_OT_loss: -5998.6505 avg_dstb_remaining_f_loss: -6182.6443 mu_2moment_loss: 5789.5406 g_constraint_loss: -7.3555 W2_loss: 70.4313
# Train_Epoch: 3 [24000/60000 (40%)] avg_dstb_g_OT_loss: -5998.6505 avg_dstb_remaining_f_loss: -6182.6443 mu_2moment_loss: 5789.5406 g_constraint_loss: -7.3555 W2_loss: 70.4313
# Train_Epoch: 3 [24000/60000 (40%)] avg_dstb_g_OT_loss: -5998.6505 avg_dstb_remaining_f_loss: -6182.6443 mu_2moment_loss: 5789.5406 g_constraint_loss: -7.3555 W2_loss: 70.4313
# Train_Epoch: 3 [25000/60000 (42%)] avg_dstb_g_OT_loss: -6186.1147 avg_dstb_remaining_f_loss: -6428.4452 mu_2moment_loss: 5954.7387 g_constraint_loss: -7.4103 W2_loss: 73.8345
# Train_Epoch: 3 [25000/60000 (42%)] avg_dstb_g_OT_loss: -6186.1147 avg_dstb_remaining_f_loss: -6428.4452 mu_2moment_loss: 5954.7387 g_constraint_loss: -7.4103 W2_loss: 73.8345
# Train_Epoch: 3 [25000/60000 (42%)] avg_dstb_g_OT_loss: -6186.1147 avg_dstb_remaining_f_loss: -6428.4452 mu_2moment_loss: 5954.7387 g_constraint_loss: -7.4103 W2_loss: 73.8345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 60
#      55 """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
#      56                     Real Training Process
#      57 """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
#      59 for epoch in range(1, cfg.epochs + 1):
# ---> 60     train(epoch, csv_path)
#      61     if cfg.schedule_learning_rate:
#      62         if epoch % cfg.lr_schedule_per_epoch == 0:
#
# Cell In[9], line 70, in train(epoch, csv_path)
#      68 # Get the gradient of g(y):=g(miu_i_data)
#      69 tmp_miu_i = miu_i[:, :, i]
# ---> 70 g_of_y = convex_g[i](tmp_miu_i).sum()
#      71 grad_g_of_y = torch.autograd.grad(
#      72     g_of_y, tmp_miu_i, create_graph=True)[0]
#      74 # For each distribution you need to calculate a f(gradient of y)
#      75 # it's the mean of the batch
#
# File ~/opt/anaconda3/envs/WB/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/WB/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/GitHub/Repo/WB_Algo/ICNN_Fan/optimal_transport_modules/icnn_modules.py:226, in ICNN_LastInp_Quadratic.forward(self, input)
#     222 for i in range(self.num_layer - 1):
#     223     x = self.activation[i](self.convex[i](
#     224         x).add(self.normal[i](input)))
# --> 226 x = self.last_convex(x).add(self.last_linear(input).pow(2))
#     228 return x
#
# File ~/opt/anaconda3/envs/WB/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/WB/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/anaconda3/envs/WB/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
